# %%
# !conda create -n latte python=3.10 pytorch torchvision pytorch-cuda=12.1 -c pytorch -c nvidia -y
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 26.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/latte
#
#   added / updated specs:
#     - python=3.10
#     - pytorch
#     - pytorch-cuda=12.1
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       7_kmp_llvm           8 KB  conda-forge
#     blas-2.116                 |              mkl          13 KB  conda-forge
#     blas-devel-3.9.0           |   16_linux64_mkl          12 KB  conda-forge
#     brotli-python-1.2.0        |  py310h25d4438_3         358 KB  conda-forge
# ...

# %%
# !/opt/conda/envs/latte/bin/pip install timm "diffusers[torch]==0.24.0" accelerate tensorboard einops transformers scikit-image decord pandas imageio-ffmpeg sentencepiece beautifulsoup4 ftfy omegaconf

# %%
# !conda install -n latte -c conda-forge openh264 -y
# Out:
# /opt/conda/pkgs/openh264-2.1.1-h780b84a_0.tar.bz2
# /opt/conda/pkgs/openh264-2.1.1-h780b84a_0
# /opt/conda/pkgs/openh264-2.1.1-h780b84a_0/lib/pkgconfig/openh264.pc
# /opt/conda/pkgs/openh264-2.1.1-h780b84a_0/lib/libopenh264.so.2.1.1
# /opt/conda/pkgs/openh264-2.1.1-h780b84a_0/lib/libopenh264.a
# /opt/conda/pkgs/openh264-2.1.1-h780b84a_0/lib/libopenh264.so
# /opt/conda/pkgs/openh264-2.1.1-h780b84a_0/lib/libopenh264.so.6
# /opt/conda/envs/mostgan/lib/python3.9/site-packages/av.libs/libopenh264-7bd47c3a.so.2.6.0
# /opt/conda/envs/latte/conda-meta/openh264-2.1.1-h780b84a_0.json
# /opt/conda/envs/latte/lib/pkgconfig/openh264.pc
# /opt/conda/envs/latte/lib/libopenh264.a
# /opt/conda/envs/latte/lib/libopenh264.so
# /opt/conda/envs/latte/lib/libopenh264.so.2.1.1
# /opt/conda/envs/latte/lib/libopenh264.so.6

# %%
# !/opt/conda/envs/latte/bin/pip install "av==12.0.0"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 12.7 MB/s  0:00:02m0:00:0100:01
# ...

# %%
# !/opt/conda/envs/latte/bin/python -c "import av; print(av.__version__)"
# Out:
# 12.0.0

# %%
# !/opt/conda/envs/latte/bin/pip install "huggingface_hub==0.20.3" "transformers==4.36.2" "accelerate==0.25.0" "tokenizers==0.15.0"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 47.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 29.5 MB/s  0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.28.0
#     Uninstalling huggingface_hub-1.28.0:
#       Successfully uninstalled huggingface_hub-1.28.0
#   Attempting uninstall: tokenizers━━━━━━━━━━━━━━ 0/4 [huggingface_hub]
#     Found existing installation: tokenizers 0.22.20/4 [huggingface_hub]
#     Uninstalling tokenizers-0.22.2:━━━━━━━━━ 0/4 [huggingface_hub]
#       Successfully uninstalled tokenizers-0.22.2 0/4 [huggingface_hub]
#   Attempting uninstall: accelerate90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [tokenizers]
#     Found existing installation: accelerate 1.14.0━━━━━━━━━━━━ 1/4 [tokenizers]
#     Uninstalling accelerate-1.14.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/4 [tokenizers]
#       Successfully uninstalled accelerate-1.14.0━━━━━━━━━━━━━━ 1/4 [tokenizers]
# ...

# %%
# !/opt/conda/envs/latte/bin/python -c "import torch; print(torch.__version__); print(torch.cuda.is_available())"
# Out:
# 2.5.1
# True

# %%
# !/opt/conda/envs/latte/bin/python -c "import av; import torch; print('AV:', av.__version__); print('PyTorch:', torch.__version__); print('CUDA:', torch.cuda.is_available())"
# Out:
# AV: 12.0.0
# PyTorch: 2.5.1
# CUDA: True
